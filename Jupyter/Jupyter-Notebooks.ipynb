# %% [markdown]
# ## Jupyter Notebooks
# by Tom Hohenstein
#
#
# Feel free to try jupyter while we talk
#
# https://try.jupyter.org/

# %% [markdown]
# ## Background
#
# + Started as IPython Notebook under Fernando Pérez
# + Jupyter launched in 2014 as a continuation of the IPython Project
# + Sponsored by the Sloan Foundation, Moore Foundation, Google, Microsoft, Rackspace, and few institutions (UC-Berkley and CalPoly)
# + [Kernels for 40 other languages](https://github.com/ipython/ipython/wiki/IPython-kernels-for-other-languages)

# %% [markdown]
# ## Interface overview
#
# - Cover navigation
# - review icons
# - talk about cells
# - show kernel 'on'

# %% [markdown]
# ## Capabilities
# What can we do with a Jupyter Notebook?

# %%
# code 

for x in "abcd": 
    print(x)
    print("hello")
# Out:
# a
# hello
# b
# hello
# c
# hello
# d
# hello

# %%
# %%bash
#
# ls -F
# Out:
# Fix.ipynb
# Instruction_Stats.ipynb
# Jupyter-Notebooks.ipynb
# assh_test.csv
# code/
# dataset-4552-20181009103137.csv
# libinsight-dataset.csv
# notebook.tex
# output_35_0.png
# output_36_0.png
# output_37_0.png
# output_39_0.png
# output_60_1.png
# output_60_3.png
# output_60_5.png
# re-test.csv
# test.csv

# %% [markdown]
# Write Markdown
# + List 1
# + List 2

# %% [markdown]
# <img src="http://svs.gsfc.nasa.gov/vis/a010000/a012000/a012021/JupiterThumbnailSmall.png" alt="Jupyter" style="width: 400px;"/>

# %%
from IPython.display import HTML

# Youtube - from http://www.polyphant.com/2016/05/10/jupyter-video.html
HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/JxNqXzXfL1U" frameborder="0" allowfullscreen></iframe>')
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/JxNqXzXfL1U" frameborder="0" allowfullscreen></iframe>

# %%
# audio 
import IPython
IPython.display.display(IPython.display.Audio(url="https://ccrma.stanford.edu/~urinieto/drop/090412-Incendios.mp3"))
# from http://stackoverflow.com/questions/33048353/more-than-one-audio-object-in-a-jupyter-ipython-notebook-cell
# Out:
#                 <audio controls="controls" >
#                     <source src="https://ccrma.stanford.edu/~urinieto/drop/090412-Incendios.mp3" type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#
# requires some additional help 
# https://github.com/ellisonbg/ipyleaflet
from ipyleaflet import Map, basemaps, basemap_to_tiles
m = Map(
    layers=(basemap_to_tiles(basemaps.NASAGIBS.ModisTerraTrueColorCR, "2017-04-08"), ),
    center=(52.204793, 360.121558),
    zoom=4 
)
m
# Out:
# Map(basemap={'url': 'https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', 'max_zoom': 19, 'attribution': 'Map …

# %%
# http://jupyter.org/widgets.html
import numpy as np
import bqplot.pyplot as plt

size = 100

plt.figure(title='Scatter plot with colors') 
plt.scatter(np.random.randn(size), np.random.randn(size), color=np.random.randn(size))
plt.show()
# Out:
# VBox(children=(Figure(axes=[ColorAxis(scale=ColorScale()), Axis(scale=LinearScale()), Axis(orientation='vertic…

# %% [markdown]
# You can also do 3-d with [pythreejs](http://jupyter.org/widgets.html)

# %%
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

print (__version__) # requires version >= 1.9.0
init_notebook_mode(connected=True)
# Out:
# 3.1.1
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
import plotly.graph_objs as go

import numpy as np

x = np.random.randn(2000)
y = np.random.randn(2000)
iplot([go.Histogram2dContour(x=x, y=y, contours=dict(coloring='heatmap')),
       go.Scatter(x=x, y=y, mode='markers', marker=dict(color='white', size=3, opacity=0.3))], show_link=False)
# Out:
# <div id="c7f1ffc9-6cee-4b3a-a24e-ed79e3c31e6d" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("c7f1ffc9-6cee-4b3a-a24e-ed79e3c31e6d", [{"contours": {"coloring": "heatmap"}, "x": [-2.1854087094117927, 0.09916905394855406, -0.004607594688440949, -0.480497558760797, 0.8462930758250158, -0.7874885980993761, -2.203644675523176, -1.472236162289649, -2.5789823295042758, 0.13627407641797556, -0.5339076403497558, -0.8680459064345235, -0.8088387134921696, -0.9527727865414805, 1.3192004348949014, -1.3994374199478998, -0.5847946338995386, 0.08394930199